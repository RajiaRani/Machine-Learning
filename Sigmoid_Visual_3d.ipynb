# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
# Define the Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
import numpy as np
import plotly.graph_objects as go

# Define sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# define positive and negative data points
positive_points = np.array([[2, 3], [4, 5], [3, 6], [5, 4]])
negative_points = np.array([[-2, -3], [-4, -5], [-3, -6], [-5, -4]])

# Create a grid of 'x' and 'y' values
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)

# Define weights and bias
w1, w2, b = 1, 1, 0

# Compute Z = w1*x + w2*y + b
Z = w1 * X + w2 * Y + b

# Apply sigmoid
S = sigmoid(Z)

# ✅ Compute boundary line (decision boundary)
boundary_x = np.linspace(-10, 10, 100)
boundary_y = -(w1 * boundary_x + b) / w2

# Positive points
positive_trace = go.Scatter3d(
    x=positive_points[:, 0],
    y=positive_points[:, 1],
    z=np.full(positive_points.shape[0], 0),
    mode='markers',
    marker=dict(size=5, color='blue', opacity=0.8),
    name='Positive Points'
)

# Negative points
negative_trace = go.Scatter3d(
    x=negative_points[:, 0],
    y=negative_points[:, 1],
    z=np.full(negative_points.shape[0], 0),
    mode='markers',
    marker=dict(size=5, color='red', opacity=0.8),
    name='Negative Points'
)

# Sigmoid surface
sigmoid_surface = go.Surface(
    x=X, 
    y=Y,
    z=S,
    opacity=0.6,
    colorscale='Viridis',
    showscale=False,
    name='Sigmoid Surface'
)

# ✅ Classifier boundary
boundary_trace = go.Scatter3d(
    x=boundary_x,
    y=boundary_y,
    z=np.full_like(boundary_x, 0.5),
    mode='lines',
    line=dict(color='green', width=6),
    name='Classifier Boundary'
)

# Combine all traces
fig = go.Figure(data=[positive_trace, negative_trace, sigmoid_surface, boundary_trace])

# Layout
fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Sigmoid(Z)',
        zaxis=dict(nticks=4, range=[0, 1]),
        camera=dict(up=dict(x=0, y=0, z=1), eye=dict(x=2, y=2, z=0.1))
    ),
    title='Interactive 3D Sigmoid Surface with Decision Boundary'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 56
#      43 sigmoid_surface = go.Surface(
#      44     x=X,
#      45     y=Y,
#    (...)
#      50     name='Sigmoid Surface'
#      51 )
#      54 # Create trace for the classifier boundary
#      55 boundary_trace= go.Scatter(
# ---> 56     x=boundary_x,
#      57     y=boundary_y,
#      58     z=np.full_like(boundary_x, 0.5),
#      59     mode='lines',
#      60     line=dict(color='green', width=6),
#      61     name='Classifier Boundary'
#      62 )
#      64 # Create figure object
#      65 fig = go.Figure(data=[positive_trace, negative_trace, sigmoid_surface, boundary_trace])
#
# NameError: name 'boundary_x' is not defined
