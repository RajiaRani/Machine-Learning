# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# define positive and negative data points
positive_points = np.array([ [2, 3], [4, 5], [3, 6], [5,4]])
negative_points = np.array([[-2, -3], [-4, -5], [-3, -6], [-5, -4]])

# Create a grid of 'x' and 'y' values
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x,y)

# Define weights and biases for the 2D classifier
w1, w2, b = 1, 1, 0

# compute 'z' as a linear combination of 'x' and 'y'
Z = w1 * X + w2 * Y + b

# Evaluate the Sigmoid function
S = sigmoid(Z)
