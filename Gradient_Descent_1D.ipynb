# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loss function
def f(x):
    return x**2

# Derivative of the Loss function
def df(x):
    return 2*x

# Gradient Descent parameters
x_satrt = 9 # Intital Guess
learning_rate = 0.15
n_iterations = 10

# For storing the iteartions steps for visualization
x_steps = [x_satrt]
y_steps = [f(x_satrt)]


# Values for Plotting the parabola
x = np.linspace(-10, 10, 400)
y = f(x)
